# %% [markdown]
# TUGAS

# %%
class Node:
    def __init__(self, name):
        self.name = name
        self.next = None

class CircularLinkedList:
    def __init__(self):  #
        self.head = None

    def append(self, name):
        new_node = Node(name)
        if not self.head:
            self.head = new_node
            self.head.next = self.head
        else:
            temp = self.head
            while temp.next != self.head:
                temp = temp.next
            temp.next = new_node
            new_node.next = self.head

    def print_schedule(self, days=14):
        if not self.head:
            print("Jadwal kosong.")
            return

        temp = self.head
        for day in range(1, days + 1):
            print(f"Hari {day}: {temp.name}")
            temp = temp.next  # Perbaikan: hanya pindah satu langkah per hari

# Input nama satpam
satpam_list = CircularLinkedList()
for i in range(4):
    name = input(f"Masukkan nama satpam ke-{i+1}: ")
    satpam_list.append(name)

# Cetak jadwal piket selama 14 hari
print("\n📅 Jadwal Piket Satpam Selama 2 Minggu:\n")
satpam_list.print_schedule(14)
# Out:
# Masukkan nama satpam ke-1: Ilyasa Abiyyu Wicaksono
# Masukkan nama satpam ke-2: Senandung
# Masukkan nama satpam ke-3: Farrel
# Masukkan nama satpam ke-4: Zurich Sabil
#
# 📅 Jadwal Piket Satpam Selama 2 Minggu:
#
# Hari 1: Ilyasa Abiyyu Wicaksono
# Hari 2: Senandung
# Hari 3: Farrel
# Hari 4: Zurich Sabil
# Hari 5: Ilyasa Abiyyu Wicaksono
# Hari 6: Senandung
# Hari 7: Farrel
# Hari 8: Zurich Sabil
# Hari 9: Ilyasa Abiyyu Wicaksono
# Hari 10: Senandung
# Hari 11: Farrel
# Hari 12: Zurich Sabil
# Hari 13: Ilyasa Abiyyu Wicaksono
# Hari 14: Senandung
